# %%
a=['a','b']
a[1]
# Out:
# 'b'

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #rtt 전처리된 데이터 추가

# %%
df1=pd.read_csv('./add_data/add.csv')
df2=pd.read_csv('./data/original/train.csv')

# %%
df1.drop(['Unnamed: 0.2','Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
df = pd.concat([df1, df2])
# 중복 데이터 제거
df = df.drop_duplicates(subset=['sentence_1','sentence_2'])

# %%
df
# Out:
#                                id                     source  \
# 0      boostcamp-sts-v1-train-000      nsmc-sampled-s1-rtted
# 1      boostcamp-sts-v1-train-002  petition-sampled-s1-rtted
# 2      boostcamp-sts-v1-train-004     slack-sampled-s1-rtted
# 3      boostcamp-sts-v1-train-007      nsmc-sampled-s1-rtted
# 4      boostcamp-sts-v1-train-008  petition-sampled-s1-rtted
# ...                           ...                        ...
# 9319  boostcamp-sts-v1-train-9319           petition-sampled
# 9320  boostcamp-sts-v1-train-9320           petition-sampled
# 9321  boostcamp-sts-v1-train-9321           petition-sampled
# 9322  boostcamp-sts-v1-train-9322              slack-sampled
# 9323  boostcamp-sts-v1-train-9323           petition-sampled
#
#                                  sentence_1  \
# 0     스릴과 반전이 있고, 여타 쓰레기 같은 한국영화와는 차원이 다르다.
# 1                         입주신청 조건을 변경해 주세요.
# 2                              정말 자랑스럽습니다!!
# 3                        이렇게 귀여운 쥐는 처음 봅니다.
# 4                       미세먼지 해결이 가장 시급한 문제!
# ...                                     ...
# 9319   교원능력개발평가에서 교원이 보호받을 수 있는 장치를 마련해야합니다
# 9320                        여성가족부의 폐지를 원합니드
# 9321                        국회의원들 월급좀 줄여주세요
# 9322          오늘 못한 점심은 다음에 다시 츄라이 하기로 해요!!
# 9323                       법정공휴일 휴무관련 (근로자)
#
#                                          sentence_2  label  binary-label
# 0                              반전도 있고,사랑도 있고재미도있네요.    2.1           0.0
# 1                                주택청약 무주택기준 변경해주세요.    1.0           0.0
# 2                             꼬옥 실제로 한번 뵈어요 뿌뿌뿌~!~!   -0.1           0.0
# 3                                이렇게 지겨운 공포영화는 처음..    0.6           0.0
# 4                           가장 시급한 것이 신생아실 관리입니다!!!    0.3           0.0
# ...                                             ...    ...           ...
# 9319  본인이 납부한 국민연금 금액을 기준으로 대출을 받을 수 있는 제도를 마련해 주세요    0.2           0.0
# 9320                              여성가족부 폐지를 청원 합니다.    4.2           1.0
# 9321                               공무원 봉급좀 줄이지좀 마세요    0.6           0.0
# 9322                       오늘 못먹은 밥은 꼭 담에 먹기로 하고요!!    3.2           1.0
# 9323                         법정공휴일의 유급휴무화를 막아야 합니다.    1.4           0.0
#
# [19664 rows x 6 columns]

# %%
df.to_csv('./data/train.csv')

# %%
df1[df1['label']<0]
# Out:
#                                 id                     source  \
# 2       boostcamp-sts-v1-train-004     slack-sampled-s1-rtted
# 9       boostcamp-sts-v1-train-020     slack-sampled-s1-rtted
# 14      boostcamp-sts-v1-train-038      nsmc-sampled-s1-rtted
# 15      boostcamp-sts-v1-train-041  petition-sampled-s1-rtted
# 17      boostcamp-sts-v1-train-046     slack-sampled-s1-rtted
# ...                            ...                        ...
# 10502  boostcamp-sts-v1-train-9266   petition-sampleds2-rtted
# 10508  boostcamp-sts-v1-train-9278   petition-sampleds2-rtted
# 10519  boostcamp-sts-v1-train-9308      slack-sampleds2-rtted
# 10522  boostcamp-sts-v1-train-9313       nsmc-sampleds2-rtted
# 10523  boostcamp-sts-v1-train-9315      slack-sampleds2-rtted
#
#                              sentence_1                         sentence_2  \
# 2                          정말 자랑스럽습니다!!              꼬옥 실제로 한번 뵈어요 뿌뿌뿌~!~!
# 9                     새로운 머리를 하셨습니다. ^^           가방에 넣어 다니면서 조금씩 먹습니다. ^^
# 14                   암튼 걷는다는 설정이 좀 -_-;            허나 알리슨 로먼이 벗은건 충격 -_-;;
# 15                           나이가 문제인가요?                         저는 무엇인가요??
# 17                       내가 왜 냄비에 들어갔지?            저는 사과나 우유에 프로틴타서 먹어요 ㅎㅎ
# ...                                 ...                                ...
# 10502  국민연금 .. 어려운이들에게는 희망이될수있게 자율해지를..       병원비 2000만원 남은건 집뿐인데 팔게 도와주세요
# 10508                    대한민국 정치인이 참~~~            조국 ~~~ 조국 ~~~ 나의 조국 ~~~
# 10519                베이비 필터 끼우고 찍어봤습니당.                        나는 매우 행복했다.
# 10522          엘호야때문에보긴하지만...루즈한감있습니다..  ..글쎄... 충격적이지만 노골적일때까지...;; 이상하다.
# 10523    의견 1) 제게 우리 회사는 6-a 창작자인것 같네요!  네, 서귀포는 20일이었으니 7~10일은 걸린 것 같습니다.
#
#        label  binary-label
# 2       -0.1           0.0
# 9       -0.1           0.0
# 14      -0.1           0.0
# 15      -0.1           0.0
# 17      -0.1           0.0
# ...      ...           ...
# 10502   -0.1           0.0
# 10508   -0.1           0.0
# 10519   -0.1           0.0
# 10522   -0.1           0.0
# 10523   -0.1           0.0
#
# [3044 rows x 6 columns]
